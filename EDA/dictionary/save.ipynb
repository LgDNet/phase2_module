# %%
# Customer type & Sub type
customer_type2 = \
{
    'end customers': [
        'end customer',
        'construction company',
        'owner/developer',
        'medical/healthcare facility',
        'government/public sector',
        'corporate',
        'education',
        'retail',
        'fitness',
        'manufacturer',
        'distributor/wholesaler',
        'installer'
    ],
    'channel partners': [
        'channel partner',
        'agent',
        'distributor',
        'reseller',
        'nsp(us only)',
        'national reseller',
        'regional reseller',
        'si(system integrator)',
        'pro av/av consultant',
        'var(3po)'
    ],
    'specifiers influencers': [
        'specifiers influencer',
        'architect',
        'consultant',
        'contractor',
        'technical/design firm',
        'region builder',
        'installer',
        'ad&contents provider',
        'applied rep'
    ],
    'solution eco partners': [
        'solution eco partner',
        'cms/webos/isv',
        'mount/metal fabrication',
        'meeting solution',
        'control/processor',
        'external compute'
    ],
    'service partners': [
        'service partner',
        'authorized service center',
        'authorized service dealer'
    ],
    'business customer': [
        'business customer'
    ],
    'lg partner': [
        'lg partner'
    ],
    'distributor': [
        'distributor:'
    ],
    'manufacturer': [
        'manufacturer'
    ],
    'others': [
        'other','others'
    ],
    "specifier influencer": ["specifier influencer"],
    "channel partner": ["channel partner"],
    "service partner": ["service partner"],
    "solution eco partner": ["solution eco partner"],
    "installer contractor": ["installer contractor"],
    "corporate": ["corporate"],
    "hvac engineer": ["hvac engineer"],
    "engineer": ["engineer"],
    "developer": ["developer"],
    "technician": ["technician"],
    "homeowner": ["homeowner"],
    "consultant": ["consultant"]
}

# Job function
job_function = {
    'community and social services': ['community and social services'],
    'purchasing': ['purchasing'],
    'operations': ['operations'],
    'curation': ['curation'],
    'administrative': ['administrative'],
    'military and protective services': ['military and protective services'],
    'education': ['education'],
    'film production': ['film production'],
    'media and communication': ['media and communication'],
    'consulting': ['consulting'],
    'entrepreneurship': ['entrepreneurship'],
    'research': ['research'],
    'accounting': ['accounting'],
    'healthcare services': ['healthcare services'],
    'engineering': ['engineering'],
    'graphic/color art': ['graphic/color art'],
    '3d/vfx art': ['3d/vfx art'],
    'arts and design': ['arts and design'],
    'real estate': ['real estate'],
    'legal': ['legal'],
    'business development': ['business development'],
    'sales': ['sales'],
    'program and project management': ['program and project management'],
    'quality assurance': ['quality assurance'],
    'human resources': ['human resources'],
    'support': ['support'],
    'others': ['others','other'],
    'information technology': ['information technology'],
    'finance': ['finance'],
    'marketing': ['marketing'],
    'product management': ['product management'],
    "clinical specialist": ["clinical specialist"],
    "radiology professional": ["radiology professional"],
    "medical imaging specialist": ["medical imaging specialist"],
    "medical solution provider": ["medical solution provider"],
    "surgery professional": ["surgery professional"],
    "owner": ["owner"],
    "manager": ["manager"],
    "pathologist": ["pathologist"],
    "project manager": ["project manager"],
    "art and design": ["art and design"],
    "general management": ["general management"],
    "miscellaneous": ["miscellaneous"],
    "buyer": ["buyer"],
    "technical": ["technical"],
    "creation and design": ["creation and design"],
    "lead": ["lead"],
    "architect consultant": ["architect consultant"],
    "purchaser": ["purchaser"],
    "director": ["director"],
    "executive": ["executive"],
    "designer": ["designer"],
    "program and project management": ["program and project management"],
    "sales": ["sales"],
    "media and communication": ["media and communication"],
    "engineer": ["engineer"],
    "general manager": ["general manager"],
    "finance": ["finance"],
    "gm": ["gm"],
    "architect": ["architect"]
}

# seniority_level
seniority_level = {\
    'partner': ['partner'],
    'c-level executive': ['c-level executive','ceo/founder'],
    'vice president': ['vice president'],
    'director': ['director'],
    'manager': ['manager'],
    'associate/analyst': ['associate/analyst'],
    'entry level': ['entry level'],
    'trainee': ['trainee'],
    'intern': ['intern'],
    'others': ['others', 'other'],
    'c-level executive': ['c-level executive'],
    'trainee': ['trainee'],
    'vice president': ['vice president'],
    'end-user': ['end-user'],
    'hospital': ['hospital'],
    'installer': ['installer'],
    'government': ['government'],
    'cargo': ['cargo'],
    'software/solution provider':['software/solution provider'],
    'manufacturer': ['manufacturer'],
    'consultant': ['consultant'],
    'homeowner': ['homeowner'],
    'decision': ['decision'],
    'engineering': ['engineering'],
    'none':['none']
}

with open('customer_type2.pickle', 'wb') as fw:
    pickle.dump(customer_type2, fw)

with open('job_function.pickle', 'wb') as fw:
    pickle.dump(job_function, fw)

with open('seniority_level.pickle', 'wb') as fw:
    pickle.dump(seniority_level, fw)

# %%
# fill customer_type value

for col in ['customer_type','customer_job','customer_position']:
    for key,value in customer_type2.items():
        for val in value:
            true_list=[]
            val = re.sub("(&|-|/|:)","",val).replace(' ','').lower()
            
            true_list=list(customer_df.loc[customer_df[col].str.contains(val, na=False)].index)
            customer_df.loc[(customer_df['customer_type2'].isnull()) & (customer_df.index.isin(true_list)), 'customer_type2']=key

customer_df.loc[(customer_df['customer_type'].notnull())&customer_df['customer_type2'].isnull(),'customer_type2']='etc'

# fill job_function value

for col in ['customer_job','customer_type','customer_position']:
    for key,value in job_function.items():
        for val in value:
            true_list=[]
            val = re.sub("(&|-|/|:)","",val).replace(' ','').lower()
            
            true_list=list(customer_df.loc[customer_df[col].str.contains(val, na=False)].index)
            customer_df.loc[(customer_df['job_function'].isnull()) & (customer_df.index.isin(true_list)), 'job_function']=key

customer_df.loc[(customer_df['customer_job'].notnull())&customer_df['job_function'].isnull(),'job_function']='etc'

# fill seniority level

for col in ['customer_position', 'customer_type','customer_job']:
    for key,value in seniority_level.items():
        for val in value:
            true_list=[]
            val = re.sub("(&|-|/|:)","",val).replace(' ','').lower()
            
            true_list=list(customer_df.loc[customer_df[col].str.contains(val, na=False)].index)
            customer_df.loc[(customer_df['seniority_level'].isnull()) & (customer_df.index.isin(true_list)), 'seniority_level']=key

customer_df.loc[(customer_df['customer_position'].notnull())&customer_df['seniority_level'].isnull(),'seniority_level']='etc'
